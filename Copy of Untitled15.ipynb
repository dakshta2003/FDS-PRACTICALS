# %%
Row=int(input("Enter the Row numbers:"))
Col=int(input("enter the Col numbers:"))

print("enter the element for matrix1:")
matrix1=[[int(input())for i in range (Col)] for j in range(Row)]
for i in range(Row):
    for j in range(Col):
        print(format(matrix1[i][j],"<3"),end="")
    print()
print("enter the elements for matrix2:")
matrix2=[[int(input())for i in range(Col)]for j in range(Row)]
print("matrix2:")
for i in range(Row):
    for j in range(Col):
        print(format(matrix2[i][j],"<3"),end="")
    print()
result=[[0 for i in range(Col)]for j in range(Row)]
for i in range(Row):
       for j in range(Col):
           result[i][j]=matrix1[i][j] + matrix2[i][j]
print("result is:")         
for i in range(Row):
  for j in range(Col):
      print(format(result[i][j],"<3"),end="")
      print()
for i in range(Row):
  for j in range(Col):
      result[i][j]=matrix1[i][j]-matrix2[i][j]
      print("result is:")
      print(format(result[i][j],"<3"),end="")
      print()
# Out:
# Enter the Row numbers:2
# enter the Col numbers:2
# enter the element for matrix1:
# 1
# 2
# 3
# 4
# 1  2
# 3  4
# enter the elements for matrix2:
# 5
# 5
# 6
# 7
# matrix2:
# 5  5
# 6  7
# result is:
# 6
# 7
# 9
# 11
# result is:
# -4
# result is:
# -3
# result is:
# -3
# result is:
# -3
